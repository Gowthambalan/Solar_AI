# %%
! pip install requests

# %%
import json
import requests
from datetime import datetime

# %%
! pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in d:\ai projects\powerthon\venv\lib\site-packages (8.1.7)
# Requirement already satisfied: comm>=0.1.3 in d:\ai projects\powerthon\venv\lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in d:\ai projects\powerthon\venv\lib\site-packages (from ipywidgets) (9.6.0)
# Requirement already satisfied: traitlets>=4.3.1 in d:\ai projects\powerthon\venv\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in d:\ai projects\powerthon\venv\lib\site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in d:\ai projects\powerthon\venv\lib\site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: colorama in d:\ai projects\powerthon\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in d:\ai projects\powerthon\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in d:\ai projects\powerthon\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\ai projects\powerthon\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in d:\ai projects\powerthon\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\ai projects\powerthon\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in d:\ai projects\powerthon\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in d:\ai projects\powerthon\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in d:\ai projects\powerthon\venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\ai projects\powerthon\venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in d:\ai projects\powerthon\venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\ai projects\powerthon\venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in d:\ai projects\powerthon\venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from IPython.display import display
import ipywidgets as widgets

upload = widgets.FileUpload(accept='.json', multiple=False)
display(upload)
# Out:
# FileUpload(value=(), accept='.json', description='Upload')

# %%
if upload.value:
    uploaded_file = list(upload.value.values())[0]
    data = json.loads(uploaded_file['content'].decode('utf-8'))
    print("✅ JSON Loaded Successfully")
else:
    print("❌ Please upload a JSON file above.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 if upload.value:
# ----> 2     uploaded_file = list(upload.value.values())[0]
#       3     data = json.loads(uploaded_file['content'].decode('utf-8'))
#       4     print("✅ JSON Loaded Successfully")
#
# AttributeError: 'tuple' object has no attribute 'values'
